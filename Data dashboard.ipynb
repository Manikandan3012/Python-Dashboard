# %%
# !pip install dash

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install plotly

# %%
import pandas as pd
import dash
from dash import dcc
from dash import html
import plotly.express as px

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data.csv')
df.head(5)
# Out:
#   Cause of Suicide       Gender  Andaman & Nicobar Islands  Andhra Pradesh  \
# 0   Sleeping Pills         Male                          0              11
# 1   Sleeping Pills       Female                          0              11
# 2   Sleeping Pills  Transgender                          0               0
# 3   Sleeping Pills        Total                          0              22
# 4         Drowning         Male                          2             161
#
#    Arunachal Pradesh  Assam  Bihar  Chandigarh  Chhattisgarh  \
# 0                  0     28     10           0             7
# 1                  0     12     16           0             1
# 2                  0      0      0           0             0
# 3                  0     40     26           0             8
# 4                  7     95     12           1            18
#
#    Dadra & Nagar Haveli  ...  Puducherry  Punjab  Rajasthan  Sikkim  \
# 0                     0  ...           0      12         25       0
# ...

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
   html.H1(children=' Cause of Diseases Dashboard'),
   html.Div(children='''
       Analyzing the Cause of Suicide using Plotly Dash
   '''),
   dcc.Graph(
       id='histogram',
       figure={
           'data': [
               {'x': df['Cause of Suicide'], 'type': 'histogram', 'name': 'Cause of Suicide'},
           ],
           'layout': {
               'title': 'histogram-Cause of Suicide'
           }
       }
   ),
   dcc.Graph(
       id='boxplot',
       figure={
           'data': [
               {'y': df['Gender'], 'type': 'box', 'name': 'Gender'},
           ],
           'layout': {
               'title': 'Gender wise Analysis-box plot'
           }
       }
   ),
   dcc.Graph(
       id='scatterplot',
       figure={
           'data': [
               {'x': df['Cause of Suicide'], 'y': df['Tamil Nadu'], 'mode': 'Rajasthan', 'name': 'Cause of Suicide vs Tamil Nadu'},
           ],
           'layout': {
               'title': 'Cause of Suicide vs Tamil Nadu'
           }
       }
   ),
   dcc.Graph(
       id='barchart',
       figure={
           'data': [
               {'x': df['Tamil Nadu'], 'type': 'bar', 'name': 'Tamil Nadu'},
           ],
           'layout': {
               'title': 'Tamil Nadu cases'
           }
       }
   ),
   dcc.Graph(
       id='mosaicplot',
       figure=px.histogram(df, x="Cause of Suicide", color="Gender", barmode="overlay", nbins=10, width=800, height=500)
   )
    ])

# %%
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Mar/2023 14:05:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 14:05:11] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_1m1679629304.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 14:05:11] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_1m1679629304.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 14:05:11] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_1m1679629304.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 14:05:11] "GET /_dash-component-suites/dash/deps/react@16.v2_9_1m1679629304.14.0.min.js HTTP/1.1" 200 -
# ...
